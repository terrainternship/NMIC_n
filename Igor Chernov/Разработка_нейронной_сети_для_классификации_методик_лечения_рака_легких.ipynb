# %% [markdown]
# **Загрузка библиотек**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Загрузка датасетов:**

# %% [markdown]
# **Загрузка калькулятора принятия решений**

# %%
# Загрузка файла из облака в colab
import gdown
file_id = '1px7SR6N7kyTQxdswDKCd7Oyjcg8dpgFM'
gdown.download (f"https://drive.google.com/uc?id={file_id}", None, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1px7SR6N7kyTQxdswDKCd7Oyjcg8dpgFM
# To: /content/Calc.csv
# 100%|██████████| 16.6k/16.6k [00:00<00:00, 19.9MB/s]
# 'Calc.csv'

# %%
# Загрузка данных из файла
data_calc = pd.read_csv('Calc.csv')
data_calc.head()
# Out:
#   Вариант\nстадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст  \
# 0  IIIаI плоскоклеточный  Первая да (врастание в ...
# 1  IIIб плоскоклеточный  Первая да (врастание в к...
# 2  IIIаI неплоскоклеточный Первая да (врастание в...
# 3  IIIб неплоскоклеточный Первая да (врастание в ...
# 4  IIIаI мелкоклеточный Первая да (врастание в кр...
#
#    Unnamed: 1            Ответ эксперта (Лактионов) Вариант ХТ  \
# 0         NaN  переход на вариант лечения IV стадии        NaN
# 1         NaN  переход на вариант лечения IV стадии        NaN
# 2         NaN  переход на вариант лечения IV стадии        NaN
# 3         NaN  переход на вариант лечения IV стадии        NaN
# 4         NaN  переход на вариант лечения IV стадии        NaN
#
#   Поставьте галочку, если  уверены на 100% Если 75% Если 50%  \
# 0                                    False    False    False
# 1                                    False    False    False
# ...

# %%
# Отобразим первые несколько строк
print("Первые 7 строк:")
print()
data_calc.head(7)
# Out:
# Первые 7 строк:
#   Вариант\nстадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст  \
# 0  IIIаI плоскоклеточный  Первая да (врастание в ...
# 1  IIIб плоскоклеточный  Первая да (врастание в к...
# 2  IIIаI неплоскоклеточный Первая да (врастание в...
# 3  IIIб неплоскоклеточный Первая да (врастание в ...
# 4  IIIаI мелкоклеточный Первая да (врастание в кр...
# 5  IIIб мелкоклеточный Первая да (врастание в кру...
# 6        IIIаI плоскоклеточный  Первая нет 0-1 До 70
#
#    Unnamed: 1            Ответ эксперта (Лактионов)               Вариант ХТ  \
# 0         NaN  переход на вариант лечения IV стадии                      NaN
# 1         NaN  переход на вариант лечения IV стадии                      NaN
# 2         NaN  переход на вариант лечения IV стадии                      NaN
# 3         NaN  переход на вариант лечения IV стадии                      NaN
# 4         NaN  переход на вариант лечения IV стадии                      NaN
# ...

# %%
# Отображаем последние несколько строк
print("Последние 5 строк:")
print()
data_calc.tail()
# Out:
# Последние 5 строк:
#    Вариант\nстадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст  \
# 70             IIIаI мелкоклеточный Первая нет 3+ >70
# 71              IIIб мелкоклеточный Первая нет 3+ >70
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
#
#     Unnamed: 1 Ответ эксперта (Лактионов) Вариант ХТ  \
# 70        92.0                        NaN        NaN
# 71        93.0                        NaN        NaN
# 72       106.0                        NaN        NaN
# 73       107.0                        NaN        NaN
# 74       108.0                        NaN        NaN
#
#    Поставьте галочку, если  уверены на 100% Если 75% Если 50%  \
# 70                                    False    False    False
# 71                                    False    False    False
# 72                                      NaN      NaN      NaN
# ...

# %%
# Отображаем общее количество строк и столбцов
print("Размер датасета:")
print()
data_calc.shape
# Out:
# Размер датасета:
# (75, 10)

# %%
# Отображаем информацию о типах данных и заполненности ячеек
print("Информация о данных:")
print()
data_calc.info()
# Out:
# Информация о данных:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 10 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   Вариант
# стадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст  72 non-null     object
#  1   Unnamed: 1                                                                                 36 non-null     float64
#  2   Ответ эксперта (Лактионов)                                                                 42 non-null     object
#  3   Вариант ХТ                                                                                 6 non-null      object
#  4   Поставьте галочку, если  уверены на 100%                                                   72 non-null     object
# ...

# %%
# Статистика по количественным признакам
print("Статистика по количественным признакам:")
data_calc.describe()
# Out:
# Статистика по количественным признакам:
#        Unnamed: 1  Альтернатива, если 50% - обязательно  Вариант ХТ.1  \
# count   36.000000                                   0.0           0.0
# mean    54.500000                                   NaN           NaN
# std     32.102069                                   NaN           NaN
# min      1.000000                                   NaN           NaN
# 25%     30.750000                                   NaN           NaN
# 50%     54.500000                                   NaN           NaN
# 75%     78.250000                                   NaN           NaN
# max    108.000000                                   NaN           NaN
#
#        Комментарий
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
#  Подсчитываем непустые (ненулевые) значения в каждом столбце
data_calc.count()
# Out:
# Вариант\nстадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст    72
# Unnamed: 1                                                                                    36
# Ответ эксперта (Лактионов)                                                                    42
# Вариант ХТ                                                                                     6
# Поставьте галочку, если  уверены на 100%                                                      72
# Если 75%                                                                                      72
# Если 50%                                                                                      72
# Альтернатива, если 50% - обязательно                                                           0
# Вариант ХТ.1                                                                                   0
# Комментарий                                                                                    0
# ...

# %%
#  Подсчитываем уникальные значения в каждом столбце
data_calc.nunique()
# Out:
# Вариант\nстадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст    72
# Unnamed: 1                                                                                    36
# Ответ эксперта (Лактионов)                                                                     2
# Вариант ХТ                                                                                     2
# Поставьте галочку, если  уверены на 100%                                                       2
# Если 75%                                                                                       1
# Если 50%                                                                                       1
# Альтернатива, если 50% - обязательно                                                           0
# Вариант ХТ.1                                                                                   0
# Комментарий                                                                                    0
# ...

# %% [markdown]
# **Загрузка комбинаций поддержки после ПХТ 3 стадии**

# %%
file_id = '1StibINHcBTQ2JtIlrL9ZBlMGv2Nrv9eo'
gdown.download (f"https://drive.google.com/uc?id={file_id}", None, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1StibINHcBTQ2JtIlrL9ZBlMGv2Nrv9eo
# To: /content/Kombinacii.csv
# 100%|██████████| 109M/109M [00:01<00:00, 63.2MB/s]
# 'Kombinacii.csv'

# %%
# Загрузка данных из файла
data_kombi = pd.read_csv('Kombinacii.csv')
data_kombi.head()
# Out:
#    id_ответа       Раса       Пол Возраст      Статус курения  ECOG  \
# 0          1  Азиатская   Мужской   До 70   В настоящее время   0-1
# 1          2  Азиатская   Мужской   До 70   В настоящее время   0-1
# 2          3  Азиатская   Мужской   До 70   В настоящее время   0-1
# 3          4  Азиатская   Мужской   До 70   В настоящее время   0-1
# 4          5  Азиатская   Мужской   До 70   В настоящее время   0-1
#
#   Есть опухолевая нагрузка? (симптомная опухоль) Ко-мутации KRAS  \
# 0                                             да              да
# 1                                             да              да
# 2                                             да              да
# 3                                             да              да
# 4                                             да              да
#
#   Ко-мутации p53. Ко-мутации STK11  ... Срок от окончания ХЛТ  \
# 0              да               да  ...            до 42 дней
# ...

# %%
# Параметр index_col определяет столбец, который будет использоваться как индекс
data_kombi = pd.read_csv('Kombinacii.csv', index_col=0)

# Выводим первых 7 строчек таблицы
data_kombi.head(7)
# Out:
#                 Раса       Пол Возраст      Статус курения  ECOG  \
# id_ответа
# 1          Азиатская   Мужской   До 70   В настоящее время   0-1
# 2          Азиатская   Мужской   До 70   В настоящее время   0-1
# 3          Азиатская   Мужской   До 70   В настоящее время   0-1
# 4          Азиатская   Мужской   До 70   В настоящее время   0-1
# 5          Азиатская   Мужской   До 70   В настоящее время   0-1
# 6          Азиатская   Мужской   До 70   В настоящее время   0-1
# 7          Азиатская   Мужской   До 70   В настоящее время   0-1
#
#           Есть опухолевая нагрузка? (симптомная опухоль) Ко-мутации KRAS  \
# id_ответа
# 1                                                     да              да
# 2                                                     да              да
# 3                                                     да              да
# 4                                                     да              да
# ...

# %%
# Отображаем последние несколько строк
print("Последние 5 строк:")
data_kombi.tail()
# Out:
# Последние 5 строк:
#              Раса       Пол Возраст                            Статус курения  \
# id_ответа
# 248828     Другая   Женский     >70   Курение в прошлом (бросил более 1 года)
# 248829     Другая   Женский     >70   Курение в прошлом (бросил более 1 года)
# 248830     Другая   Женский     >70   Курение в прошлом (бросил более 1 года)
# 248831     Другая   Женский     >70   Курение в прошлом (бросил более 1 года)
# 248832     Другая   Женский     >70   Курение в прошлом (бросил более 1 года)
#
#           ECOG Есть опухолевая нагрузка? (симптомная опухоль) Ко-мутации KRAS  \
# id_ответа
# 248828       2                                            нет             нет
# 248829       2                                            нет             нет
# 248830       2                                            нет             нет
# 248831       2                                            нет             нет
# ...

# %%
# Отображаем общее количество строк и столбцов
print("Размер датасета:")
data_kombi.shape
# Out:
# Размер датасета:
# (248832, 20)

# %%
# Отображаем информацию о типах данных и заполненности ячеек
print("Информация о данных:")
data_kombi.info()
# Out:
# Информация о данных:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 248832 entries, 1 to 248832
# Data columns (total 20 columns):
#  #   Column                                                    Non-Null Count   Dtype
# ---  ------                                                    --------------   -----
#  0   Раса                                                      248832 non-null  object
#  1   Пол                                                       248832 non-null  object
#  2   Возраст                                                   248832 non-null  object
#  3   Статус курения                                            248832 non-null  object
#  4   ECOG                                                      248832 non-null  object
#  5   Есть опухолевая нагрузка? (симптомная опухоль)            248832 non-null  object
#  6   Ко-мутации KRAS                                           248832 non-null  object
# ...

# %%
# Статистика по количественным признакам
print("Статистика по количественным признакам:")
data_kombi.describe()
# Out:
# Статистика по количественным признакам:
#              Раса       Пол Возраст      Статус курения    ECOG  \
# count      248832    248832  248832              248832  248832
# unique          3         2       2                   3       2
# top     Азиатская   Мужской   До 70   В настоящее время     0-1
# freq        82944    124416  124416               82944  124416
#
#        Есть опухолевая нагрузка? (симптомная опухоль) Ко-мутации KRAS  \
# count                                          248832          248832
# unique                                              2               2
# top                                                да              да
# freq                                           124416          124416
#
#        Ко-мутации p53. Ко-мутации STK11 Ко-мутации KEAP1  \
# count           248832           248832           248832
# unique               2                2                2
# top                 да               да               да
# ...

# %%
#  Подсчитываем непустые (ненулевые) значения в каждом столбце
data_kombi.count()
# Out:
# Раса                                                        248832
# Пол                                                         248832
# Возраст                                                     248832
# Статус курения                                              248832
# ECOG                                                        248832
# Есть опухолевая нагрузка? (симптомная опухоль)              248832
# Ко-мутации KRAS                                             248832
# Ко-мутации p53.                                             248832
# Ко-мутации STK11                                            248832
# Ко-мутации KEAP1                                            248832
# Срок от окончания ХЛТ                                       248832
# Молекулярный статус (только для неплоскоклеточного рака)    248832
# PD-L1 статус                                                248832
# Предпочтение пациента по ответу на терапию                  248832
# ...

# %%
#  Подсчитываем уникальные значения в каждом столбце
data_kombi.nunique()
# Out:
# Раса                                                         3
# Пол                                                          2
# Возраст                                                      2
# Статус курения                                               3
# ECOG                                                         2
# Есть опухолевая нагрузка? (симптомная опухоль)               2
# Ко-мутации KRAS                                              2
# Ко-мутации p53.                                              2
# Ко-мутации STK11                                             2
# Ко-мутации KEAP1                                             2
# Срок от окончания ХЛТ                                        3
# Молекулярный статус (только для неплоскоклеточного рака)     6
# PD-L1 статус                                                 3
# Предпочтение пациента по ответу на терапию                   2
# Ответ эксперта (Лактионов)                                   4
# ...

# %%
# Перебираем все названия столбцов и для каждого выводим список уникальных значений
for name, values in data_kombi.items():
  print("Столбец",name, ":", data_kombi[name].unique())
# Out:
# Столбец Раса : ['Азиатская' 'Европейская' 'Другая']
# Столбец Пол : [' Мужской' ' Женский']
# Столбец Возраст : [' До 70' ' >70']
# Столбец Статус курения : [' В настоящее время'
#  ' Курение в прошлом (бросил более 1 месяца до 1 года)'
#  ' Курение в прошлом (бросил более 1 года)']
# Столбец ECOG : [' 0-1' '2']
# Столбец Есть опухолевая нагрузка? (симптомная опухоль) : [' да' ' нет']
# Столбец Ко-мутации KRAS : [' да' ' нет']
# Столбец Ко-мутации p53. : [' да' ' нет']
# Столбец Ко-мутации STK11 : [' да' ' нет']
# Столбец Ко-мутации KEAP1 : [' да' ' нет']
# Столбец Срок от окончания ХЛТ : ['до 42 дней' 'от 43 до 60 дней' 'более 61 дня']
# Столбец Молекулярный статус (только для неплоскоклеточного рака) : [' нет мутаций' ' не исследовались' ' EGFR редкий вариант' ' EGFR ex19'
#  ' EGFR ex21' ' ALK позитивный']
# Столбец PD-L1 статус : [' Не исследовался' ' Менее 1%' ' Более 1%']
# ...

# %%
plt.scatter(x=data_kombi['Возраст'], y=data_kombi['Статус курения'])

# %%
data_kombi['Молекулярный статус (только для неплоскоклеточного рака)'].value_counts().iloc[:70].plot(kind='bar')
# plt.title('График Рас')
plt.show()

# %%
plt.scatter(x=data_kombi['Возраст'], y=data_kombi['Комментарий'])

# %%
plt.scatter(x=data_kombi['Пол'], y=data_kombi['Возраст'])
