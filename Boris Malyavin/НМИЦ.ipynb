# %%
import gdown
import pandas as pd

# %%
# Загрузка таблицы

gdown.download('https://drive.google.com/uc?id=1QF5Ar3ZI37NsJ_YVYChE5SSi8QxGOAmX', None)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1QF5Ar3ZI37NsJ_YVYChE5SSi8QxGOAmX
# To: /content/PHT3.csv
# 100%|██████████| 109M/109M [00:01<00:00, 55.2MB/s]
# 'PHT3.csv'

# %%
bd = pd.read_csv('PHT3.csv')
bd
# Out:
#         id_ответа       Раса       Пол Возраст  \
# 0               1  Азиатская   Мужской   До 70
# 1               2  Азиатская   Мужской   До 70
# 2               3  Азиатская   Мужской   До 70
# 3               4  Азиатская   Мужской   До 70
# 4               5  Азиатская   Мужской   До 70
# ...           ...        ...       ...     ...
# 248827     248828     Другая   Женский     >70
# 248828     248829     Другая   Женский     >70
# 248829     248830     Другая   Женский     >70
# 248830     248831     Другая   Женский     >70
# 248831     248832     Другая   Женский     >70
#
#                                   Статус курения  ECOG  \
# 0                              В настоящее время   0-1
# 1                              В настоящее время   0-1
# 2                              В настоящее время   0-1
# 3                              В настоящее время   0-1
# 4                              В настоящее время   0-1
# ...                                          ...   ...
# ...

# %%
bd.count()
# Out:
# id_ответа                                                   248832
# Раса                                                        248832
# Пол                                                         248832
# Возраст                                                     248832
# Статус курения                                              248832
# ECOG                                                        248832
# Есть опухолевая нагрузка? (симптомная опухоль)              248832
# Ко-мутации KRAS                                             248832
# Ко-мутации p53.                                             248832
# Ко-мутации STK11                                            248832
# Ко-мутации KEAP1                                            248832
# Срок от окончания ХЛТ                                       248832
# Молекулярный статус (только для неплоскоклеточного рака)    248832
# PD-L1 статус                                                248832
# ...

# %%
bd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248832 entries, 0 to 248831
# Data columns (total 21 columns):
#  #   Column                                                    Non-Null Count   Dtype
# ---  ------                                                    --------------   -----
#  0   id_ответа                                                 248832 non-null  int64
#  1   Раса                                                      248832 non-null  object
#  2   Пол                                                       248832 non-null  object
#  3   Возраст                                                   248832 non-null  object
#  4   Статус курения                                            248832 non-null  object
#  5   ECOG                                                      248832 non-null  object
#  6   Есть опухолевая нагрузка? (симптомная опухоль)            248832 non-null  object
# ...

# %%
bd.describe(include=['O'])
# Out:
#              Раса       Пол Возраст      Статус курения    ECOG  \
# count      248832    248832  248832              248832  248832
# unique          3         2       2                   3       2
# top     Азиатская   Мужской   До 70   В настоящее время     0-1
# freq        82944    124416  124416               82944  124416
#
#        Есть опухолевая нагрузка? (симптомная опухоль) Ко-мутации KRAS  \
# count                                          248832          248832
# unique                                              2               2
# top                                                да              да
# freq                                           124416          124416
#
#        Ко-мутации p53. Ко-мутации STK11 Ко-мутации KEAP1  \
# count           248832           248832           248832
# unique               2                2                2
# top                 да               да               да
# freq            124416           124416           124416
#
# ...

# %%
data = bd.groupby(['Срок от окончания ХЛТ']).count()
data
# Out:
#                        id_ответа   Раса    Пол  Возраст  Статус курения  \
# Срок от окончания ХЛТ
# более 61 дня               82944  82944  82944    82944           82944
# до 42 дней                 82944  82944  82944    82944           82944
# от 43 до 60 дней           82944  82944  82944    82944           82944
#
#                         ECOG  Есть опухолевая нагрузка? (симптомная опухоль)  \
# Срок от окончания ХЛТ
# более 61 дня           82944                                           82944
# до 42 дней             82944                                           82944
# от 43 до 60 дней       82944                                           82944
#
#                        Ко-мутации KRAS  Ко-мутации p53.  Ко-мутации STK11  \
# Срок от окончания ХЛТ
# более 61 дня                     82944            82944             82944
# до 42 дней                       82944            82944             82944
# ...
