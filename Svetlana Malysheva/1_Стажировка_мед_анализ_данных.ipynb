# %% [markdown]
# Загрузка и запись данных

# %%
import pandas as pd # Загружаем модуль pandas

# %%
data = pd.read_csv('Калькулятор принятия решения.xlsx - ХЛТ_1 половина (исправлено).csv') # С помощью метода read_csv загружаем файл wine_base.csv и записываем данные в data

# %%
data.head() # С помощью метода head выводим первые 5 строк нашего ДатаФрейма
# Out:
#   Вариант\nстадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст  \
# 0  IIIаI плоскоклеточный  Первая да (врастание в ...
# 1  IIIб плоскоклеточный  Первая да (врастание в к...
# 2  IIIаI неплоскоклеточный Первая да (врастание в...
# 3  IIIб неплоскоклеточный Первая да (врастание в ...
# 4  IIIаI мелкоклеточный Первая да (врастание в кр...
#
#    Unnamed: 1            Ответ эксперта (Лактионов) Вариант ХТ  \
# 0         NaN  переход на вариант лечения IV стадии        NaN
# 1         NaN  переход на вариант лечения IV стадии        NaN
# 2         NaN  переход на вариант лечения IV стадии        NaN
# 3         NaN  переход на вариант лечения IV стадии        NaN
# 4         NaN  переход на вариант лечения IV стадии        NaN
#
#   Поставьте галочку, если  уверены на 100% Если 75% Если 50%  \
# 0                                    False    False    False
# 1                                    False    False    False
# 2                                    False    False    False
# 3                                    False    False    False
# 4                                    False    False    False
#
#    Альтернатива, если 50% - обязательно  Вариант ХТ.1  Комментарий
# 0                                   NaN           NaN          NaN
# 1                                   NaN           NaN          NaN
# 2                                   NaN           NaN          NaN
# 3                                   NaN           NaN          NaN
# 4                                   NaN           NaN          NaN

# %%
data.shape # Параметр .shape показывает размерность нашего датафрейма
# Out:
# (75, 10)

# %%
data.size # Параметр .size показывает количество элементов в нашем датафрейме
# Out:
# 750

# %%
data.count() # Метод count считает сколько всего непустых записей в каждом столбце
# Out:
# Вариант\nстадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст    72
# Unnamed: 1                                                                                    36
# Ответ эксперта (Лактионов)                                                                    42
# Вариант ХТ                                                                                     6
# Поставьте галочку, если  уверены на 100%                                                      72
# Если 75%                                                                                      72
# Если 50%                                                                                      72
# Альтернатива, если 50% - обязательно                                                           0
# Вариант ХТ.1                                                                                   0
# Комментарий                                                                                    0
# dtype: int64

# %%
data.info() # Метод .info() показывает тип каждого столбца и занимаемую память
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 10 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   Вариант
# стадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст  72 non-null     object
#  1   Unnamed: 1                                                                                 36 non-null     float64
#  2   Ответ эксперта (Лактионов)                                                                 42 non-null     object
#  3   Вариант ХТ                                                                                 6 non-null      object
#  4   Поставьте галочку, если  уверены на 100%                                                   72 non-null     object
#  5   Если 75%                                                                                   72 non-null     object
#  6   Если 50%                                                                                   72 non-null     object
#  7   Альтернатива, если 50% - обязательно                                                       0 non-null      float64
#  8   Вариант ХТ.1                                                                               0 non-null      float64
#  9   Комментарий                                                                                0 non-null      float64
# dtypes: float64(4), object(6)
# memory usage: 6.0+ KB

# %%
data.dtypes # Параметр .dtypes показывает просто тип каждого столбца
# Out:
# Вариант\nстадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст     object
# Unnamed: 1                                                                                    float64
# Ответ эксперта (Лактионов)                                                                     object
# Вариант ХТ                                                                                     object
# Поставьте галочку, если  уверены на 100%                                                       object
# Если 75%                                                                                       object
# Если 50%                                                                                       object
# Альтернатива, если 50% - обязательно                                                          float64
# Вариант ХТ.1                                                                                  float64
# Комментарий                                                                                   float64
# dtype: object

# %%
data.isna().head() # Метод .isna() вместо каждого значения подставит True (значение NaN) или False (действительное значение)
# Out:
#    Вариант\nстадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Unnamed: 1  Ответ эксперта (Лактионов)  Вариант ХТ  \
# 0        True                       False        True
# 1        True                       False        True
# 2        True                       False        True
# 3        True                       False        True
# 4        True                       False        True
#
#    Поставьте галочку, если  уверены на 100%  Если 75%  Если 50%  \
# 0                                     False     False     False
# 1                                     False     False     False
# 2                                     False     False     False
# 3                                     False     False     False
# 4                                     False     False     False
#
#    Альтернатива, если 50% - обязательно  Вариант ХТ.1  Комментарий
# 0                                  True          True         True
# 1                                  True          True         True
# 2                                  True          True         True
# 3                                  True          True         True
# 4                                  True          True         True

# %%
data.isna().sum() # Подсчитаем количество пропусков в каждом столбце с помощью метода .sum()
# Out:
# Вариант\nстадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст     3
# Unnamed: 1                                                                                    39
# Ответ эксперта (Лактионов)                                                                    33
# Вариант ХТ                                                                                    69
# Поставьте галочку, если  уверены на 100%                                                       3
# Если 75%                                                                                       3
# Если 50%                                                                                       3
# Альтернатива, если 50% - обязательно                                                          75
# Вариант ХТ.1                                                                                  75
# Комментарий                                                                                   75
# dtype: int64

# %%
proc = data.isna().sum().sum() # Подсчитаем сколько всего пропусков (во всех столбцах) в нашем датафрейме
print(proc) # Отобразим количество посчитанных пропусков
# Out:
# 378

# %%
# Переведем полученное значение в процентное отображение
proc = data.isna().sum().sum() / data.size
print(round(100*proc,1), '%', sep='')
# Out:
# 50.4%

# %%
data.fillna("НЕТ данных").head(10) # С помощью метода .fillna() заменяем все пропуски словом НЕТ данных
# Out:
#   Вариант\nстадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст  \
# 0  IIIаI плоскоклеточный  Первая да (врастание в ...
# 1  IIIб плоскоклеточный  Первая да (врастание в к...
# 2  IIIаI неплоскоклеточный Первая да (врастание в...
# 3  IIIб неплоскоклеточный Первая да (врастание в ...
# 4  IIIаI мелкоклеточный Первая да (врастание в кр...
# 5  IIIб мелкоклеточный Первая да (врастание в кру...
# 6        IIIаI плоскоклеточный  Первая нет 0-1 До 70
# 7         IIIб плоскоклеточный  Первая нет 0-1 До 70
# 8       IIIаI неплоскоклеточный Первая нет 0-1 До 70
# 9        IIIб неплоскоклеточный Первая нет 0-1 До 70
#
#    Unnamed: 1            Ответ эксперта (Лактионов)               Вариант ХТ  \
# 0  НЕТ данных  переход на вариант лечения IV стадии               НЕТ данных
# 1  НЕТ данных  переход на вариант лечения IV стадии               НЕТ данных
# 2  НЕТ данных  переход на вариант лечения IV стадии               НЕТ данных
# 3  НЕТ данных  переход на вариант лечения IV стадии               НЕТ данных
# 4  НЕТ данных  переход на вариант лечения IV стадии               НЕТ данных
# 5  НЕТ данных  переход на вариант лечения IV стадии               НЕТ данных
# 6  НЕТ данных                     одномоментная ХЛТ  паклитаксел+карбоплатин
# 7  НЕТ данных                     одномоментная ХЛТ  паклитаксел+карбоплатин
# 8  НЕТ данных                     одномоментная ХЛТ  паклитаксел+карбоплатин
# 9  НЕТ данных                     одномоментная ХЛТ  паклитаксел+карбоплатин
#
#   Поставьте галочку, если  уверены на 100% Если 75% Если 50%  \
# 0                                    False    False    False
# 1                                    False    False    False
# 2                                    False    False    False
# 3                                    False    False    False
# 4                                    False    False    False
# 5                                    False    False    False
# 6                                     True    False    False
# 7                                     True    False    False
# 8                                     True    False    False
# 9                                     True    False    False
#
#   Альтернатива, если 50% - обязательно Вариант ХТ.1 Комментарий
# 0                           НЕТ данных   НЕТ данных  НЕТ данных
# 1                           НЕТ данных   НЕТ данных  НЕТ данных
# 2                           НЕТ данных   НЕТ данных  НЕТ данных
# 3                           НЕТ данных   НЕТ данных  НЕТ данных
# 4                           НЕТ данных   НЕТ данных  НЕТ данных
# 5                           НЕТ данных   НЕТ данных  НЕТ данных
# 6                           НЕТ данных   НЕТ данных  НЕТ данных
# 7                           НЕТ данных   НЕТ данных  НЕТ данных
# 8                           НЕТ данных   НЕТ данных  НЕТ данных
# 9                           НЕТ данных   НЕТ данных  НЕТ данных

# %% [markdown]
# Переименование столбцов

# %%
data_backup = data.copy() # Создаем копию нашего датафрейма и записываем в переменную data_backup
data.head()
# Out:
#   Вариант\nстадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст  \
# 0  IIIаI плоскоклеточный  Первая да (врастание в ...
# 1  IIIб плоскоклеточный  Первая да (врастание в к...
# 2  IIIаI неплоскоклеточный Первая да (врастание в...
# 3  IIIб неплоскоклеточный Первая да (врастание в ...
# 4  IIIаI мелкоклеточный Первая да (врастание в кр...
#
#    Unnamed: 1            Ответ эксперта (Лактионов) Вариант ХТ  \
# 0         NaN  переход на вариант лечения IV стадии        NaN
# 1         NaN  переход на вариант лечения IV стадии        NaN
# 2         NaN  переход на вариант лечения IV стадии        NaN
# 3         NaN  переход на вариант лечения IV стадии        NaN
# 4         NaN  переход на вариант лечения IV стадии        NaN
#
#   Поставьте галочку, если  уверены на 100% Если 75% Если 50%  \
# 0                                    False    False    False
# 1                                    False    False    False
# 2                                    False    False    False
# 3                                    False    False    False
# 4                                    False    False    False
#
#    Альтернатива, если 50% - обязательно  Вариант ХТ.1  Комментарий
# 0                                   NaN           NaN          NaN
# 1                                   NaN           NaN          NaN
# 2                                   NaN           NaN          NaN
# 3                                   NaN           NaN          NaN
# 4                                   NaN           NaN          NaN

# %%
data = data.rename(columns={'Вариант\nстадия; гистология; какая планируется линия; ECOG; противопоказания к ЛТ; возраст': 'вариант', 'Unnamed:': 'без данных', 'Ответ эксперта (Лактионов)': 'ответ эксперта', 'Вариант ХТ': 'Вариант ХТ', 'Поставьте галочку, если уверены на 100%': 'уверенность 100%'}) # Переименование столбцов
data
# Out:
#                                               вариант  Unnamed: 1  \
# 0   IIIаI плоскоклеточный  Первая да (врастание в ...         NaN
# 1   IIIб плоскоклеточный  Первая да (врастание в к...         NaN
# 2   IIIаI неплоскоклеточный Первая да (врастание в...         NaN
# 3   IIIб неплоскоклеточный Первая да (врастание в ...         NaN
# 4   IIIаI мелкоклеточный Первая да (врастание в кр...         NaN
# ..                                                ...         ...
# 70             IIIаI мелкоклеточный Первая нет 3+ >70        92.0
# 71              IIIб мелкоклеточный Первая нет 3+ >70        93.0
# 72                                                NaN       106.0
# 73                                                NaN       107.0
# 74                                                NaN       108.0
#
#                           ответ эксперта Вариант ХТ  \
# 0   переход на вариант лечения IV стадии        NaN
# 1   переход на вариант лечения IV стадии        NaN
# 2   переход на вариант лечения IV стадии        NaN
# 3   переход на вариант лечения IV стадии        NaN
# 4   переход на вариант лечения IV стадии        NaN
# ..                                   ...        ...
# 70                                   NaN        NaN
# 71                                   NaN        NaN
# 72                                   NaN        NaN
# 73                                   NaN        NaN
# 74                                   NaN        NaN
#
#    Поставьте галочку, если  уверены на 100% Если 75% Если 50%  \
# 0                                     False    False    False
# 1                                     False    False    False
# 2                                     False    False    False
# 3                                     False    False    False
# 4                                     False    False    False
# ..                                      ...      ...      ...
# 70                                    False    False    False
# 71                                    False    False    False
# 72                                      NaN      NaN      NaN
# 73                                      NaN      NaN      NaN
# 74                                      NaN      NaN      NaN
#
#     Альтернатива, если 50% - обязательно  Вариант ХТ.1  Комментарий
# 0                                    NaN           NaN          NaN
# 1                                    NaN           NaN          NaN
# 2                                    NaN           NaN          NaN
# 3                                    NaN           NaN          NaN
# 4                                    NaN           NaN          NaN
# ..                                   ...           ...          ...
# 70                                   NaN           NaN          NaN
# 71                                   NaN           NaN          NaN
# 72                                   NaN           NaN          NaN
# 73                                   NaN           NaN          NaN
# 74                                   NaN           NaN          NaN
#
# [75 rows x 10 columns]

# %% [markdown]
# Перевод в Numpy

# %%
np_data = data.values # Получаем данные из датафрейма и записываем их в переменную np_data
print(np_data.shape) # Выводим размерность np_data
np_data.dtype
# Out:
# (75, 10)
# dtype('O')

# %%
print(np_data[0]) # Выводим 0ой элемент из массива
# Out:
# ['IIIаI плоскоклеточный  Первая да (врастание в крупные магистральные сосуды, распад в легочной паренхиме с формированием абсцесса) 0-1 До 70'
#  nan 'переход на вариант лечения IV стадии' nan False False False nan nan
#  nan]

# %%
# Выведем первые 10 элементов из np_data
for i in range(10):
  print(np_data[i])
# Out:
# ['IIIаI плоскоклеточный  Первая да (врастание в крупные магистральные сосуды, распад в легочной паренхиме с формированием абсцесса) 0-1 До 70'
#  nan 'переход на вариант лечения IV стадии' nan False False False nan nan
#  nan]
# ['IIIб плоскоклеточный  Первая да (врастание в крупные магистральные сосуды, распад в легочной паренхиме с формированием абсцесса) 0-1 До 70'
#  nan 'переход на вариант лечения IV стадии' nan False False False nan nan
#  nan]
# ['IIIаI неплоскоклеточный Первая да (врастание в крупные магистральные сосуды, распад в легочной паренхиме с формированием абсцесса) 0-1 До 70'
#  nan 'переход на вариант лечения IV стадии' nan False False False nan nan
#  nan]
# ['IIIб неплоскоклеточный Первая да (врастание в крупные магистральные сосуды, распад в легочной паренхиме с формированием абсцесса) 0-1 До 70'
#  nan 'переход на вариант лечения IV стадии' nan False False False nan nan
#  nan]
# ['IIIаI мелкоклеточный Первая да (врастание в крупные магистральные сосуды, распад в легочной паренхиме с формированием абсцесса) 0-1 До 70'
#  nan 'переход на вариант лечения IV стадии' nan False False False nan nan
#  nan]
# ['IIIб мелкоклеточный Первая да (врастание в крупные магистральные сосуды, распад в легочной паренхиме с формированием абсцесса) 0-1 До 70'
#  nan 'переход на вариант лечения IV стадии' nan False False False nan nan
#  nan]
# ['IIIаI плоскоклеточный  Первая нет 0-1 До 70' nan 'одномоментная ХЛТ'
#  'паклитаксел+карбоплатин' True False False nan nan nan]
# ['IIIб плоскоклеточный  Первая нет 0-1 До 70' nan 'одномоментная ХЛТ'
#  'паклитаксел+карбоплатин' True False False nan nan nan]
# ['IIIаI неплоскоклеточный Первая нет 0-1 До 70' nan 'одномоментная ХЛТ'
#  'паклитаксел+карбоплатин' True False False nan nan nan]
# ['IIIб неплоскоклеточный Первая нет 0-1 До 70' nan 'одномоментная ХЛТ'
#  'паклитаксел+карбоплатин' True False False nan nan nan]
