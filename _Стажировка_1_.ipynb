# %%
import pandas as pd
import gdown
gdown.download('https://drive.google.com/uc?id=1f8WG1NwEG9LtYMzwTzU4bQoC80XO-3u5', None, quiet=True)
# Out:
# 'dataset1.csv'

# %%
data = pd.read_csv('dataset1.csv')
data
# Out:
#         id_ответа       Раса       Пол Возраст  \
# 0               1  Азиатская   Мужской   До 70
# 1               2  Азиатская   Мужской   До 70
# 2               3  Азиатская   Мужской   До 70
# 3               4  Азиатская   Мужской   До 70
# 4               5  Азиатская   Мужской   До 70
# ...           ...        ...       ...     ...
# 248827     248828     Другая   Женский     >70
# 248828     248829     Другая   Женский     >70
# 248829     248830     Другая   Женский     >70
# 248830     248831     Другая   Женский     >70
# 248831     248832     Другая   Женский     >70
#
#                                   Статус курения  ECOG  \
# 0                              В настоящее время   0-1
# 1                              В настоящее время   0-1
# 2                              В настоящее время   0-1
# 3                              В настоящее время   0-1
# 4                              В настоящее время   0-1
# ...                                          ...   ...
# ...

# %%
data.shape
# Out:
# (248832, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248832 entries, 0 to 248831
# Data columns (total 21 columns):
#  #   Column                                                    Non-Null Count   Dtype
# ---  ------                                                    --------------   -----
#  0   id_ответа                                                 248832 non-null  int64
#  1   Раса                                                      248832 non-null  object
#  2   Пол                                                       248832 non-null  object
#  3   Возраст                                                   248832 non-null  object
#  4   Статус курения                                            248832 non-null  object
#  5   ECOG                                                      248832 non-null  object
#  6   Есть опухолевая нагрузка? (симптомная опухоль)            248832 non-null  object
# ...

# %%
data.count()
# Out:
# id_ответа                                                   248832
# Раса                                                        248832
# Пол                                                         248832
# Возраст                                                     248832
# Статус курения                                              248832
# ECOG                                                        248832
# Есть опухолевая нагрузка? (симптомная опухоль)              248832
# Ко-мутации KRAS                                             248832
# Ко-мутации p53.                                             248832
# Ко-мутации STK11                                            248832
# Ко-мутации KEAP1                                            248832
# Срок от окончания ХЛТ                                       248832
# Молекулярный статус (только для неплоскоклеточного рака)    248832
# PD-L1 статус                                                248832
# ...

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data['ECOG'].head(10)
# Out:
# 0     0-1
# 1     0-1
# 2     0-1
# 3     0-1
# 4     0-1
# 5     0-1
# 6     0-1
# 7     0-1
# 8     0-1
# 9     0-1
# Name: ECOG, dtype: object

# %%
data_ = data.groupby(['Раса']).count()
data_
# Out:
#              id_ответа    Пол  Возраст  Статус курения   ECOG  \
# Раса
# Азиатская        82944  82944    82944           82944  82944
# Другая           82944  82944    82944           82944  82944
# Европейская      82944  82944    82944           82944  82944
#
#              Есть опухолевая нагрузка? (симптомная опухоль)  Ко-мутации KRAS  \
# Раса
# Азиатская                                             82944            82944
# Другая                                                82944            82944
# Европейская                                           82944            82944
#
#              Ко-мутации p53.  Ко-мутации STK11  Ко-мутации KEAP1  \
# Раса
# Азиатская              82944             82944             82944
# Другая                 82944             82944             82944
# Европейская            82944             82944             82944
#
#              Срок от окончания ХЛТ  \
# Раса
# Азиатская                    82944
# Другая                       82944
# ...

# %%
data_1 = data.groupby(['Пол']).count()
data_1
# Out:
#           id_ответа    Раса  Возраст  Статус курения    ECOG  \
# Пол
#  Женский     124416  124416   124416          124416  124416
#  Мужской     124416  124416   124416          124416  124416
#
#           Есть опухолевая нагрузка? (симптомная опухоль)  Ко-мутации KRAS  \
# Пол
#  Женский                                          124416           124416
#  Мужской                                          124416           124416
#
#           Ко-мутации p53.  Ко-мутации STK11  Ко-мутации KEAP1  \
# Пол
#  Женский           124416            124416            124416
#  Мужской           124416            124416            124416
#
#           Срок от окончания ХЛТ  \
# Пол
#  Женский                 124416
#  Мужской                 124416
#
#           Молекулярный статус (только для неплоскоклеточного рака)  \
# Пол
#  Женский                                             124416
#  Мужской                                             124416
#
# ...

# %%
data_1 = data.groupby(['Статус курения']).count()
data_1
# Out:
#                                                     id_ответа   Раса    Пол  \
# Статус курения
#  В настоящее время                                      82944  82944  82944
#  Курение в прошлом (бросил более 1 года)                82944  82944  82944
#  Курение в прошлом (бросил более 1 месяца до 1 ...      82944  82944  82944
#
#                                                     Возраст   ECOG  \
# Статус курения
#  В настоящее время                                    82944  82944
#  Курение в прошлом (бросил более 1 года)              82944  82944
#  Курение в прошлом (бросил более 1 месяца до 1 ...    82944  82944
#
#                                                     Есть опухолевая нагрузка? (симптомная опухоль)  \
# Статус курения
#  В настоящее время                                                                           82944
#  Курение в прошлом (бросил более 1 года)                                                     82944
# ...

# %%
data_1 = data.groupby(['ECOG']).count()
data_1
# Out:
#       id_ответа    Раса     Пол  Возраст  Статус курения  \
# ECOG
#  0-1     124416  124416  124416   124416          124416
# 2        124416  124416  124416   124416          124416
#
#       Есть опухолевая нагрузка? (симптомная опухоль)  Ко-мутации KRAS  \
# ECOG
#  0-1                                          124416           124416
# 2                                             124416           124416
#
#       Ко-мутации p53.  Ко-мутации STK11  Ко-мутации KEAP1  \
# ECOG
#  0-1           124416            124416            124416
# 2              124416            124416            124416
#
#       Срок от окончания ХЛТ  \
# ECOG
#  0-1                 124416
# 2                    124416
#
#       Молекулярный статус (только для неплоскоклеточного рака)  PD-L1 статус  \
# ECOG
#  0-1                                             124416               124416
# 2                                                124416               124416
#
# ...

# %%
data_1 = data.groupby(['Поставьте галочку, если уверены на 100%']).count()
data_1
# Out:
#                                          id_ответа    Раса     Пол  Возраст  \
# Поставьте галочку, если уверены на 100%
# False                                       158976  158976  158976   158976
# True                                         89856   89856   89856    89856
#
#                                          Статус курения    ECOG  \
# Поставьте галочку, если уверены на 100%
# False                                            158976  158976
# True                                              89856   89856
#
#                                          Есть опухолевая нагрузка? (симптомная опухоль)  \
# Поставьте галочку, если уверены на 100%
# False                                                                            158976
# True                                                                              89856
#
#                                          Ко-мутации KRAS  Ко-мутации p53.  \
# Поставьте галочку, если уверены на 100%
# ...

# %%
data_1 = data.groupby(['Если 75%']).count()
data_1
# Out:
#           id_ответа    Раса     Пол  Возраст  Статус курения    ECOG  \
# Если 75%
# False        158976  158976  158976   158976          158976  158976
# True          89856   89856   89856    89856           89856   89856
#
#           Есть опухолевая нагрузка? (симптомная опухоль)  Ко-мутации KRAS  \
# Если 75%
# False                                             158976           158976
# True                                               89856            89856
#
#           Ко-мутации p53.  Ко-мутации STK11  Ко-мутации KEAP1  \
# Если 75%
# False              158976            158976            158976
# True                89856             89856             89856
#
#           Срок от окончания ХЛТ  \
# Если 75%
# False                    158976
# True                      89856
#
#           Молекулярный статус (только для неплоскоклеточного рака)  \
# Если 75%
# False                                                158976
# ...

# %%
data_1 = data.groupby(['Если 50%']).count()
data_1
# Out:
#           id_ответа    Раса     Пол  Возраст  Статус курения    ECOG  \
# Если 50%
# False        179712  179712  179712   179712          179712  179712
# True          69120   69120   69120    69120           69120   69120
#
#           Есть опухолевая нагрузка? (симптомная опухоль)  Ко-мутации KRAS  \
# Если 50%
# False                                             179712           179712
# True                                               69120            69120
#
#           Ко-мутации p53.  Ко-мутации STK11  Ко-мутации KEAP1  \
# Если 50%
# False              179712            179712            179712
# True                69120             69120             69120
#
#           Срок от окончания ХЛТ  \
# Если 50%
# False                    179712
# True                      69120
#
#           Молекулярный статус (только для неплоскоклеточного рака)  \
# Если 50%
# False                                                179712
# ...

# %%
data_1 = data.groupby(['Альтернатива, если 50% - обязательно']).count()
data_1
# Out:
#                                       id_ответа    Раса     Пол  Возраст  \
# Альтернатива, если 50% - обязательно
# 0                                        103680  103680  103680   103680
# Алектиниб                                  4608    4608    4608     4608
# Дурвалумаб                                39168   39168   39168    39168
# Наблюдение                                73728   73728   73728    73728
# Осимертиниб                               27648   27648   27648    27648
#
#                                       Статус курения    ECOG  \
# Альтернатива, если 50% - обязательно
# 0                                             103680  103680
# Алектиниб                                       4608    4608
# Дурвалумаб                                     39168   39168
# Наблюдение                                     73728   73728
# Осимертиниб                                    27648   27648
#
# ...
