# %% [markdown]
# ##Стажировка пробное подключение библиотеки Пандас

# %%
import pandas as pd # Загружаем модуль pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/dataset1.csv")
data.head()
# Out:
#    id_ответа       Раса       Пол Возраст      Статус курения  ECOG  \
# 0          1  Азиатская   Мужской   До 70   В настоящее время   0-1
# 1          2  Азиатская   Мужской   До 70   В настоящее время   0-1
# 2          3  Азиатская   Мужской   До 70   В настоящее время   0-1
# 3          4  Азиатская   Мужской   До 70   В настоящее время   0-1
# 4          5  Азиатская   Мужской   До 70   В настоящее время   0-1
#
#   Есть опухолевая нагрузка? (симптомная опухоль) Ко-мутации KRAS  \
# 0                                             да              да
# 1                                             да              да
# 2                                             да              да
# 3                                             да              да
# 4                                             да              да
#
#   Ко-мутации p53. Ко-мутации STK11  ... Срок от окончания ХЛТ  \
# 0              да               да  ...            до 42 дней
# ...

# %%
data.shape
# Out:
# (248832, 21)

# %%
data.count()
# Out:
# id_ответа                                                   248832
# Раса                                                        248832
# Пол                                                         248832
# Возраст                                                     248832
# Статус курения                                              248832
# ECOG                                                        248832
# Есть опухолевая нагрузка? (симптомная опухоль)              248832
# Ко-мутации KRAS                                             248832
# Ко-мутации p53.                                             248832
# Ко-мутации STK11                                            248832
# Ко-мутации KEAP1                                            248832
# Срок от окончания ХЛТ                                       248832
# Молекулярный статус (только для неплоскоклеточного рака)    248832
# PD-L1 статус                                                248832
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248832 entries, 0 to 248831
# Data columns (total 21 columns):
#  #   Column                                                    Non-Null Count   Dtype
# ---  ------                                                    --------------   -----
#  0   id_ответа                                                 248832 non-null  int64
#  1   Раса                                                      248832 non-null  object
#  2   Пол                                                       248832 non-null  object
#  3   Возраст                                                   248832 non-null  object
#  4   Статус курения                                            248832 non-null  object
#  5   ECOG                                                      248832 non-null  object
#  6   Есть опухолевая нагрузка? (симптомная опухоль)            248832 non-null  object
# ...

# %%
data.dtypes
# Out:
# id_ответа                                                    int64
# Раса                                                        object
# Пол                                                         object
# Возраст                                                     object
# Статус курения                                              object
# ECOG                                                        object
# Есть опухолевая нагрузка? (симптомная опухоль)              object
# Ко-мутации KRAS                                             object
# Ко-мутации p53.                                             object
# Ко-мутации STK11                                            object
# Ко-мутации KEAP1                                            object
# Срок от окончания ХЛТ                                       object
# Молекулярный статус (только для неплоскоклеточного рака)    object
# PD-L1 статус                                                object
# ...

# %%
proc = data.isna().sum().sum() # Подсчитаем сколько всего пропусков (во всех столбцах) в нашем датафрейме
print(proc)
# Out:
# 0

# %%
data.describe()
# Out:
#            id_ответа
# count  248832.000000
# mean   124416.500000
# std     71831.755429
# min         1.000000
# 25%     62208.750000
# 50%    124416.500000
# 75%    186624.250000
# max    248832.000000

# %%
data.describe(include=['O'])
# Out:
#              Раса       Пол Возраст      Статус курения    ECOG  \
# count      248832    248832  248832              248832  248832
# unique          3         2       2                   3       2
# top     Азиатская   Мужской   До 70   В настоящее время     0-1
# freq        82944    124416  124416               82944  124416
#
#        Есть опухолевая нагрузка? (симптомная опухоль) Ко-мутации KRAS  \
# count                                          248832          248832
# unique                                              2               2
# top                                                да              да
# freq                                           124416          124416
#
#        Ко-мутации p53. Ко-мутации STK11 Ко-мутации KEAP1  \
# count           248832           248832           248832
# unique               2                2                2
# top                 да               да               да
# freq            124416           124416           124416
#
# ...
